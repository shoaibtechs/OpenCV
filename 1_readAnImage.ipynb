# %%
import cv2

# %%
# img =  cv2.imread("1.jpg") # Read an Image 
# cv2.imshow("Beautiful",img ) #Image show 
# cv2.waitKey(1000)              #Image frame wait time -ms and 0 pass keyboard any key press 
# #cv2.destroyAllWindows()    # All windows close 
# #cv2.destroyWindows()     #Only one window close

# %%
img =  cv2.imread("1.jpg") # Read an Image 
cv2.imshow("Beautiful",img ) #Image show 
cv2.imshow("Beautiful-2",img ) #Image show 
cv2.waitKey(0)              #Image frame wait time -ms and 0 pass keyboard any key press 
#cv2.destroyAllWindows()    # All windows close 
cv2.destroyWindows("Beautiful-2")     #Only one window close
# Out:
# ...
# QObject::moveToThread: Current thread (0x55d5f5097350) is not the object's thread (0x55d5f53a8140).
# Cannot move to target thread (0x55d5f5097350)
#
# QObject::moveToThread: Current thread (0x55d5f5097350) is not the object's thread (0x55d5f53a8140).
# Cannot move to target thread (0x55d5f5097350)
#
# QObject::moveToThread: Current thread (0x55d5f5097350) is not the object's thread (0x55d5f53a8140).
# Cannot move to target thread (0x55d5f5097350)
#
# QObject::moveToThread: Current thread (0x55d5f5097350) is not the object's thread (0x55d5f53a8140).
# Cannot move to target thread (0x55d5f5097350)
#
# QObject::moveToThread: Current thread (0x55d5f5097350) is not the object's thread (0x55d5f53a8140).
# Cannot move to target thread (0x55d5f5097350)
#
# QObject::moveToThread: Current thread (0x55d5f5097350) is not the object's thread (0x55d5f53a8140).
# Cannot move to target thread (0x55d5f5097350)
#
# ...
